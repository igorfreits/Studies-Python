# %% [markdown]
# Jupyter notebook é uma aplicação web que permite a execução de código em tempo
# rea, visualização de dados e textos explicativos.
# Cientistas de dados podem criar, executar o código e explicar o processo enquanto executam e mostram os dados

# %%
# Live code
print('Hello world!')
# Out:
# Hello world!

# %% [markdown]
# # Markdown - Como formatar seu texto
# Este será um texto onde posso explicar algo.
#
# Abaixo você está vendo um código multilinhas.
# ```
# if True:
#     print('Hello world!')
# ```
# Também pode ser interessante usar uma `palavra` como código.
#
# Você pode ter textos em *itálico* ou **negrito**.
#
# * Linha 1
# * Linha 2
# * Linha aninhada
#     - Outra coisa
#     - Mais uma linha
# * Retornando para lista normal
#
# Também pode ter listas enumeradas:
# 1. Linha
# 2. Linha
#     1. Aninhamento
#     2. Aninhamento
#     3. Aninhamento
# 3. Linha
# 4. Linha
# 5. Linha
#
# Abaixo uma linha horizontal
#
# ---
#
# Bloco de citação:
#
# > Um texto gigante no seu notebook.
# >
# > Mais uma linha do texto.
# >
#
# ## Outro título
#
# Aqui você verá o [link do google](https://www.google.com.br)
#
# Abaixo uma tabela HTML:
#
# | Aqui temos uma tabela | Com mais uma coluna |
# |-----------------------|---------------------|
# | Aqui temos uma linha  | Outra coluna        |
# | Aqui temos uma linha  | Outra coluna        |
# | Aqui temos uma linha  | Outra coluna        |
# | Coluna                | Outra               |
#
# Por fim, você pode usar HTML puro também, rsrs.
#
# <h1>Isso é um título</h1>
# <p>Aqui vemos um &lt;p&gt;. Você pode usar qualquer tag HTML normal.

# %% [markdown]
# # Abaixo você verá um vídeo do Youtube
# Poderia também adicionar um texto explicativo aqui.

# %%
# %%HTML
# <h1>Vídeo do youtube</h1>
# <iframe width="560" height="315" src='https://www.youtube.com/watch?v=D9G1VOjN_84' frameborder="0"></iframe>
# Out:
# <h1>Vídeo do youtube</h1>
# <iframe width="560" height="315" src='https://www.youtube.com/watch?v=D9G1VOjN_84' frameborder="0"></iframe>

# %% [markdown]
# # Criando uma classe Python

# %%
class Client:
    def __init__(self, name, last_name):
        self.name = name
        self.last_name = last_name
        
    def show_details(self):
        print(self.name)
        print(self.last_name)

clients = Client('Igor', 'Freitas')
clients.show_details()
# Out:
# Igor
# Freitas

# %%
import dados_83
#importa arquivos

# %% [markdown]
# # Comandos do sistema

# %%
# !ping 127.0.0.1
# Out:
# Disparando 127.0.0.1 com 32 bytes de dados:
# Resposta de 127.0.0.1: bytes=32 tempo<1ms TTL=128
# Resposta de 127.0.0.1: bytes=32 tempo<1ms TTL=128
# Resposta de 127.0.0.1: bytes=32 tempo<1ms TTL=128
# Resposta de 127.0.0.1: bytes=32 tempo<1ms TTL=128
#
# Estat�sticas do Ping para 127.0.0.1:
#     Pacotes: Enviados = 4, Recebidos = 4, Perdidos = 0 (0% de
#              perda),
# Aproximar um n�mero redondo de vezes em milissegundos:
#     M�nimo = 0ms, M�ximo = 0ms, M�dia = 0ms

# %% [markdown]
# # Graphics

# %%
import matplotlib.path as mpath
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt


fig, ax = plt.subplots()

Path = mpath.Path
path_data = [
    (Path.MOVETO, (1.58, -2.57)),
    (Path.CURVE4, (0.35, -1.1)),
    (Path.CURVE4, (-1.75, 2.0)),
    (Path.CURVE4, (0.375, 2.0)),
    (Path.LINETO, (0.85, 1.15)),
    (Path.CURVE4, (2.2, 3.2)),
    (Path.CURVE4, (3, 0.05)),
    (Path.CURVE4, (2.0, -0.5)),
    (Path.CLOSEPOLY, (1.58, -2.57)),
    ]
codes, verts = zip(*path_data)
path = mpath.Path(verts, codes)
patch = mpatches.PathPatch(path, facecolor='r', alpha=0.5)
ax.add_patch(patch)

# plot control points and connecting lines
x, y = zip(*path.vertices)
line, = ax.plot(x, y, 'go-')

ax.grid()
ax.axis('equal')
plt.show()

# %%
# %%timeit
list = [x * 2 for x in range(100000)] #Tempo de execução do arquivo
# Out:
# 5.07 ms ± 163 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# # Exibindo Pandas Dataframe

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(np.random.randn(18,5))
df
# Out:
#            0         1         2         3         4
# 0  -0.485326 -0.182891 -1.214559 -0.018176  0.257144
# 1  -0.897076 -0.789264 -1.259227  0.185193 -1.301634
# 2  -2.476660  1.359606  1.997220  0.695982 -0.461455
# 3   0.400279 -1.335271  0.936627 -0.702416  1.101007
# 4  -0.124942 -0.246970 -0.645284  2.199587 -1.287826
# 5   0.586760 -0.541741  0.908231 -0.525601 -0.905467
# 6  -1.563688  1.671663  1.090652 -1.161436 -0.986444
# 7   1.618106  1.315712 -1.713404  0.229294  1.291015
# 8   0.544462 -0.511921  2.257838 -1.411174  1.680664
# 9   0.987549  1.078875  0.310875  0.766980  0.451215
# 10  0.060228 -0.419232  1.506531 -0.855151  0.280947
# 11 -0.470264 -0.039543 -0.314055 -0.951051  1.615249
# 12  1.664542 -1.936305 -0.268886  0.791005 -1.591654
# 13 -0.076879 -0.495510  0.392538 -0.359448  0.175536
# 14 -1.244529 -1.528131  0.338955 -0.185212 -0.158426
# 15 -0.330991 -0.448001 -0.135395  0.607137  0.462346
# 16 -0.172057 -0.254301  0.173668 -0.424216 -0.912008
# 17 -2.815411  0.804267 -0.237066  0.351026 -0.389693
