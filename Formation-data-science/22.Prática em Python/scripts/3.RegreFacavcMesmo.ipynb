# %%
# Formação Cientista de Dados - Fernando Amaral e Jones Granatyr
# Regressão Linear, Faça você mesmo

# %%
# Importação das bibliotecas, sklearn para criar o modelo de regressão e yellowbrick para visualização de residuais
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from matplotlib import pyplot as plt

# %%
# Carregamento da base de dados e exclusão da primeira coluna
base = pd.read_csv('../dados/slr12.csv', sep=';')
base.shape
# Out:
# (36, 2)

# %%
base.head()
# Out:
#    FrqAnual  CusInic
# 0      1000     1050
# 1      1125     1150
# 2      1087     1213
# 3      1070     1275
# 4      1100     1300

# %%
# Definição das variáveis X e Y, X FrqAnual é a variável independente e Y CusInic é a variável dependente
X = base.iloc[:, 0].values
y = base.iloc[:, 1].values

X
y
# Out:
# array([1050, 1150, 1213, 1275, 1300, 1300, 1400, 1400, 1250, 1830, 1350,
#        1450, 1300, 1300, 1275, 1375, 1285, 1400, 1400, 1285, 1275, 1135,
#        1250, 1275, 1150, 1250, 1275, 1225, 1280, 1300, 1250, 1175, 1300,
#        1250, 1300, 1200], dtype=int64)

# %%
# Cálculo da correlação entre X e Y
correlacao = np.corrcoef(X, y)
correlacao[0, 1]
# Out:
# 0.4770072516802127

# %%
#formato de matriz com uma coluna a mais
X = X.reshape(-1, 1)
# Criação do modelo e treinamento (fit indica que o treinamento deve ser executado)
modelo = LinearRegression() 
modelo.fit(X, y)
# Out:
# LinearRegression()

# %%
# Geração do gráfico com os pontos reais e as previsões
plt.scatter(X, y) # Gráfico de dispersão dos pontos
plt.plot(X, modelo.predict(X), color = 'red') # Linha de tendência

# %%
#valor anual da franquina
valr =  1300
modelo.predict([[valr]]) # Previsão do valor da franquia
# Out:
# array([1352.70953897])
