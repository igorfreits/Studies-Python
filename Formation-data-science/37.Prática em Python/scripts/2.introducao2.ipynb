# %%
# Formação Cientista de Dados - Fernando Amaral e Jones Granatyr
# Igraph

# %%
# Importação das bibliotecas
from igraph import Graph
from igraph import plot

# %%
# Grafo direcionado
grafo1 = Graph(edges = [(0,1),(1,2),(2,3),(3,0)], directed = True)
grafo1.vs['label'] = range(grafo1.vcount())
print(grafo1)
# Out:
# IGRAPH D--- 4 4 --
# + attr: label (v)
# + edges:
# 0->1 1->2 2->3 3->0

# %%
# Criação Não direcionado
grafo2 = Graph(edges = [(0,1),(1,2),(2,3),(3,0)], directed = False) # Grafo não direcionado
grafo2.vs['label'] = range(grafo2.vcount())
print(grafo2)
# Out:
# IGRAPH U--- 4 4 --
# + attr: label (v)
# + edges:
# 0--1 1--2 2--3 0--3

# %%
#gráfico
plot(grafo2, bbox=(0,0,300,300))

# %%
# Adicionando vértices e arestas por meio das funções add_vertices e add_vertex
grafo3 = Graph(directed = False) # Grafo não direcionado
grafo3.add_vertices(10) # Adiciona 10 vértices
#grafo3.add_vertex(16)
grafo3.add_edges([(0,1),(2,2),(2,3),(3,0)]) # Adiciona arestas
grafo3.vs['label'] = range(grafo3.vcount()) # Adiciona rótulos aos vértices
print(grafo3) 
plot(grafo3, bbox=(0,0,300,300))
# Out:
# IGRAPH U--- 10 4 --
# + attr: label (v)
# + edges:
# 0--1 2--2 2--3 0--3

# %%
# Criação do quarto grafo, configurando rótulos personalizados para os vértices
grafo4 = Graph(directed = False) # Grafo não direcionado
grafo4.add_vertices(5) # Adiciona 5 vértices
grafo4.add_edges([(0,1),(1,2),(2,3),(3,4),(4,0),(0,2),(2,1)]) # Adiciona arestas
grafo4.add_vertex(5) # Adiciona mais um vértice
grafo4.add_vertex(6) # Adiciona mais um vértice
grafo4.vs['label'] = ['A', 'B', 'C', 'D', 'E', 'F', 'G'] # Adiciona rótulos personalizados aos vértices
# Out:
# C:\Users\igorsantos\AppData\Local\Temp\ipykernel_30380\331802614.py:5: DeprecationWarning: You are using integers as vertex names. This is discouraged because most igraph functions interpret integers as vertex _IDs_ and strings as vertex names. For sake of consistency, convert your vertex names to strings before assigning them. Future versions from igraph 0.11.0 will disallow integers as vertex names.
#   grafo4.add_vertex(5)
# C:\Users\igorsantos\AppData\Local\Temp\ipykernel_30380\331802614.py:6: DeprecationWarning: You are using integers as vertex names. This is discouraged because most igraph functions interpret integers as vertex _IDs_ and strings as vertex names. For sake of consistency, convert your vertex names to strings before assigning them. Future versions from igraph 0.11.0 will disallow integers as vertex names.
#   grafo4.add_vertex(6)

# %%
plot(grafo4, bbox=(0,0,300,300))
